# %%
from __future__ import print_function
import csv
import pandas as pd
import numpy as np
import os
import pylab as pl
import sys
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
env
# Out:
# {'CLICOLOR': '1',
#  'DFDATA': '/gws/open/NYCOpenData/nycopendata/data',
#  'GIT_PAGER': 'cat',
#  'HOME': '/home/cusp/akd361',
#  'JPY_PARENT_PID': '37658',
#  'LANG': 'en_US.UTF-8',
#  'LD_LIBRARY_PATH': '/opt/rh/v8314/root/usr/lib64:/opt/rh/nodejs010/root/usr/lib64:/opt/rh/rh-python34/root/usr/lib64:/localhome/oracle/11g-client/product/11.2.0/client_1/lib',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'PAGER': 'cat',
#  'PATH': '/opt/rh/v8314/root/usr/bin:/opt/rh/nodejs010/root/usr/bin:/opt/rh/rh-python34/root/usr/bin:/sbin:/usr/sbin:/bin:/usr/bin:/usr/local/bin',
#  'PUI2016': '/home/cusp/akd361/PUI2016',
#  'PUIDATA': '/home/cusp/akd361/PUIdata',
#  'PWD': '/wingrdp/homedirs/akd361/PUI2016_akd361',
#  'SHELL': '/bin/bash',
#  'SHLVL': '0',
#  'TERM': 'xterm-color',
#  'USER': 'akd361'}

# %%
DFDATA = os.getenv('DFDATA')

# %%
df1 = pd.read_csv(DFDATA + "/avwq-z233/1414245694/avwq-z233")

# %%
df1.columns
print(df1)
# Out:
#       License Number             Name of Licensee      License Type  \
# 0               1A10              JUHN,JAY,JAEWON         MEDALLION
# 1               1A11                YOON, DAE JIN         MEDALLION
# 2               1A12                LOUIS BELFOND         MEDALLION
# 3               1A13                 MAGDA,GAVRIL         MEDALLION
# 4               1A14             BUTTACAVOLE,JOHN         MEDALLION
# 5               1A15               TOPPA,JAWAID,A         MEDALLION
# 6               1A17           QURESHI, BASHIR A.         MEDALLION
# 7               1A18            PANTELIS, BILL P.         MEDALLION
# 8               1A19               AHMED,SHAFAYET         MEDALLION
# 9               1A20            ABRAMOWITZ, ALLEN         MEDALLION
# 10              1A21            DOUNIS, DEMITRIOS         MEDALLION
# 11              1A22               SENDOYA,LUIS,E         MEDALLION
# 12              1A23                 KAM,CHI,MING         MEDALLION
# ...

# %%
df1.head()
# Out:
#   License Number  Name of Licensee License Type Driver of Record Status  \
# 0           1A10   JUHN,JAY,JAEWON    MEDALLION            Named Driver
# 1           1A11     YOON, DAE JIN    MEDALLION       Owner Must Driver
# 2           1A12     LOUIS BELFOND    MEDALLION            Named Driver
# 3           1A13      MAGDA,GAVRIL    MEDALLION            Named Driver
# 4           1A14  BUTTACAVOLE,JOHN    MEDALLION            Named Driver
#
#   DMV License Plate                VIN  \
# 0             1A10A  1FMCU4K3XBKB54850
# 1             1A11A  2FABP7AV7BX123523
# 2             1A12A  1FMCU4K32BKA16414
# 3             1A13A  1FMCU4K3XAKA88055
# 4             1A14H  1FMCU493X9KB31021
#
#   Hybrid_Accessible_CNG_OR_Stretch_Limousine_Vehicle  Model Year  \
# 0                                                HYB        2011
# 1                                                NaN        2011
# 2                                                HYB        2011
# ...

# %%
df2 = df1 [["Model Year", "Medallion Agent Number"]]

# %%
df2.head()
# Out:
#    Model Year  Medallion Agent Number
# 0        2011                     0.0
# 1        2011                     0.0
# 2        2011                   234.0
# 3        2010                   213.0
# 4        2009                   307.0

# %%
plt.plot(df2, 'o')
plt.xlabel('Model Year')
plt.ylabel('Medallion Agent Number')
plt.title('This graph makes no sense')
plt.text(2000, 1500, 'dummy caption')
plt.legend('XY')
plt.show()

# %% [markdown]
# Hm, should have picked two variables that are actually related and would create an interesting plot.
